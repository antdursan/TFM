# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import numpy as np

# %%
# Inicializa el navegador
driver = webdriver.Chrome(executable_path='C:\Windows\System32\chromedriver.exe')

# Maximiza la ventana del navegador (abre en pantalla completa)
driver.maximize_window()

# Abre la página web
driver.get("https://www.autohero.com/es/search/")

# Lista para almacenar los enlaces
links = []

# Simula hacer scroll y carga los enlaces en cada scroll
for _ in range(100):  # Ajusta el número de scrolls según sea necesario
    # Hace scroll hasta el final de la página
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Espera a que la página se cargue después del scroll
    time.sleep(2)
    # Extrae los enlaces después de cada scroll y agrega a la lista
    enlaces = driver.find_elements(By.CSS_SELECTOR, 'a.link___2Maxt')
    for enlace in enlaces:
        links.append(enlace.get_attribute('href'))

# Elimina duplicados de la lista de enlaces
links = list(set(links))

# Cierra el navegador
driver.quit()

# %%
#Crea el dataframe con los datos de cada link
datos = pd.DataFrame()
for pagina in links[650:]:
    #si hacemos muchas consultas a la página nos echa así que vamos a poner una espera
    time.sleep(2)
    url = pagina
    r = requests.get(url)
    time.sleep(2)
    html_contents = r.text
    html_soup = BeautifulSoup(html_contents, 'html.parser')
    
    time.sleep(2)
    #Estos valores siempre aparecen en cada página
    #Vamos a sacar los elementos por su clase
    tit = html_soup.select_one('.titleText___edZSG')
    try:
        nombre = tit.text
        marca = nombre.split(' ', 1)[0]
        modelo = nombre.split(' ', 1)[1]
        precio = float(html_soup.select_one('.vehiclePrice___1uUmJ').text.strip('\xa0€').replace('.',''))
        version = html_soup.select_one('.subtitleText___2wcYx').text
        listaValores = [marca, modelo, precio, version]
        listaNombres = ['Marca', 'Modelo', 'Precio', 'Versión']

        #El resto de valores pueden o no aparecer en cada página
        #primero tratamos las etiquetas grandes de características
        carac1 = html_soup.select('.listItemValue___1IWSE')
        caracteristicas1 = [i.text for i in carac1]
        nombrecarac1 = html_soup.select('.listItemTitle___2CQBv')
        nombrecaracteristicas1 = [i.text for i in nombrecarac1]
        listaValores.extend(caracteristicas1)
        listaNombres.extend(nombrecaracteristicas1)

        #ahora se extrae la información de las tablas inferiores
        carac2 =html_soup.select('.body___2uId6')
        caracteristicas2 = [i.text for i in carac2]
        listaValores.extend(caracteristicas2)
        listaVal = [listaValores]
        nombrecarac2 =html_soup.select('.itemTitle___3GH8k')
        nombrecaracteristicas2 = [i.text for i in nombrecarac2]
        listaNombres.extend(nombrecaracteristicas2)
        datos_pagina = pd.DataFrame(listaVal,columns=listaNombres)

        datos = pd.concat([datos, datos_pagina], ignore_index=True)
    except:
        datos = datos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Crea el dataframe con los datos de cada link
# ----> 2 datos = pd.DataFrame()
#       3 for pagina in links[650:]:
#       4     #si hacemos muchas consultas a la página nos echa así que vamos a poner una espera
#       5     time.sleep(2)
#
# NameError: name 'pd' is not defined

# %%
datos
# Out:
#         Marca          Modelo   Precio                     Versión  \
# 0       Skoda          Citigo   7799.0            1.0 MPI Ambition
# 1     Citroen  C4 Spacetourer  14999.0           1.5 Blue-HDi Feel
# 2        Opel           Corsa   8099.0              1.4 Expression
# 3          MG              ZS  14399.0              1.5 VTi Luxury
# 4       Skoda           Kamiq  16899.0            1.0 TSI Ambition
# ...       ...             ...      ...                         ...
# 1007  Renault          Megane  15199.0      1.2 TCe Energy GT Line
# 1008     Audi              A4  20999.0      2.0 TDI Design quattro
# 1009  Peugeot            3008  12599.0       1.6 Blue-HDi Crossway
# 1010  Renault          Captur  21299.0  1.3 TCe Mild-Hybrid Techno
# 1011    Lexus        CT-Serie  14799.0                CT 200h -HEV
#
#      Primera matriculación Kilometraje Carburante             Transmisión  \
# 0               05.07.2016   19.507 km   Gasolina      Cambio tipo manual
# 1               27.09.2019   55.307 km     Diésel      Cambio tipo manual
# 2               30.04.2015   59.429 km   Gasolina      Cambio tipo manual
# 3               31.10.2022   88.984 km   Gasolina      Cambio tipo manual
# 4               16.12.2019     5993 km   Gasolina      Cambio tipo manual
# ...                    ...         ...        ...                     ...
# 1007            31.01.2018   56.256 km   Gasolina      Cambio tipo manual
# 1008            29.09.2016  106.137 km     Diésel  Cambio tipo automático
# 1009            10.06.2015   45.063 km     Diésel      Cambio tipo manual
# 1010            29.11.2022     2522 km   Gasolina      Cambio tipo manual
# 1011            14.06.2016  120.890 km    Híbrido  Cambio tipo automático
#
#              Potencia               Tracción  ...      Estándar de calidad  \
# 0       60 CV / 44 kW     Tracción delantera  ...  Ver estándar de calidad
# 1      131 CV / 96 kW     Tracción delantera  ...  Ver estándar de calidad
# 2       90 CV / 66 kW     Tracción delantera  ...  Ver estándar de calidad
# 3      106 CV / 78 kW     Tracción delantera  ...  Ver estándar de calidad
# 4      116 CV / 85 kW     Tracción delantera  ...  Ver estándar de calidad
# ...               ...                    ...  ...                      ...
# 1007   132 CV / 97 kW     Tracción delantera  ...                      NaN
# 1008  190 CV / 140 kW  Tracción total (4x4)   ...  Ver estándar de calidad
# 1009   120 CV / 88 kW     Tracción delantera  ...  Ver estándar de calidad
# 1010  140 CV / 103 kW     Tracción delantera  ...  Ver estándar de calidad
# 1011  136 CV / 100 kW     Tracción delantera  ...  Ver estándar de calidad
#
#      País de origen Número de llaves Coche accidentado y reparado  \
# 0            España                2                           No
# 1            España                2                           No
# 2            España                2                           No
# 3            España                2                           No
# 4            España                2                           No
# ...             ...              ...                          ...
# 1007         España                1                          NaN
# 1008         España                2                           No
# 1009         España                2                           No
# 1010         España                2                           No
# 1011         España                2                           No
#
#      La última revisión se realizó el      Historial de revisiones  \
# 0                          12.03.2024  Ver historial de revisiones
# 1                          12.03.2024  Ver historial de revisiones
# 2                          29.04.2024  Ver historial de revisiones
# 3                          23.06.2023  Ver historial de revisiones
# 4                          03.10.2023  Ver historial de revisiones
# ...                               ...                          ...
# 1007                              NaN                          NaN
# 1008                       13.12.2023  Ver historial de revisiones
# 1009                       29.02.2024  Ver historial de revisiones
# 1010                       05.12.2023  Ver historial de revisiones
# 1011                       19.03.2024  Ver historial de revisiones
#
#            Tipo de IVA ITV válida hasta Matricula Número de inventario
# 0     IVA no deducible       13.07.2024   9958JRH              FJ27714
# 1     IVA no deducible       13.10.2025   7578LBK              EH84421
# 2     IVA no deducible       04.05.2025   9896JFD              MT22167
# 3     IVA no deducible       27.10.2026   8050MBZ              KK46355
# 4     IVA no deducible       16.12.2025   9421LDD              ZM23393
# ...                ...              ...       ...                  ...
# 1007  IVA no deducible              NaN   0051KHF              PL11771
# 1008  IVA no deducible       21.03.2025   2742JSY              CC37637
# 1009  IVA no deducible       22.06.2025   7371JGB              KY56106
# 1010  IVA no deducible       29.11.2026   3180MCN              UM92200
# 1011  IVA no deducible       18.06.2024   9113JPR              LZ62073
#
# [1012 rows x 32 columns]

# %%
datos.to_excel('coches1.xlsx',index=False)
